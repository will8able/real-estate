# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
# import necessary libraries
from bs4 import BeautifulSoup
import requests
import re
  
  
# function to extract html document from given url
def getHTMLdocument(url):
      
    # request for HTML document of given url
    response = requests.get(url)
      
    # response will be provided in JSON format
    return response.text
  
    
# assign required credentials
# assign URL
url_to_scrape = "http://ldsnet.fairfaxcounty.gov/landusesrch/LUStreets.aspx?startswith=A"
  
# create document
html_document = getHTMLdocument(url_to_scrape)
  
# create soap object
soup = BeautifulSoup(html_document, 'html.parser')

# find all the anchor tags with "href" 
# attribute starting with "https://"
for link in soup.find_all('a', 
                          attrs={'href': re.compile("")}):
    # display the actual urls
    print(link.get('href'))
# Out:
# /
# https://www.fairfaxcounty.gov/search/
# https://www.fairfaxcounty.gov/
# https://www.fairfaxcounty.gov/residents/
# https://www.fairfaxcounty.gov/business/
# https://www.fairfaxcounty.gov/government/
# https://www.fairfaxcounty.gov/
# https://www.fairfaxcounty.gov/services/
# https://www.fairfaxcounty.gov/connect/
# https://www.fairfaxcounty.gov/search/
# #ctl00_smpBreadcrumbs_SkipLink
# http://www.fairfaxcounty.gov
# http://ldsnet.fairfaxcounty.gov/ldsnet/
# /LandUseSrch/Default.aspx
# LUStreets.aspx?startswith=A
# LUStreets.aspx?startswith=B
# LUStreets.aspx?startswith=C
# LUStreets.aspx?startswith=D
# LUStreets.aspx?startswith=E
# LUStreets.aspx?startswith=F
# LUStreets.aspx?startswith=G
# LUStreets.aspx?startswith=H
# LUStreets.aspx?startswith=I
# LUStreets.aspx?startswith=J
# LUStreets.aspx?startswith=K
# LUStreets.aspx?startswith=L
# LUStreets.aspx?startswith=M
# LUStreets.aspx?startswith=N
# LUStreets.aspx?startswith=O
# LUStreets.aspx?startswith=P
# ...

# %%
# import necessary libraries
from bs4 import BeautifulSoup
import requests
import re
  
  
# function to extract html document from given url
def getHTMLdocument(url):
      
    # request for HTML document of given url
    response = requests.get(url)
      
    # response will be provided in JSON format
    return response.text
  
    
# assign required credentials
# assign URL
url_to_scrape = "http://ldsnet.fairfaxcounty.gov/landusesrch/Default.aspx?strname=Marmion+Dr"
  
# create document
html_document = getHTMLdocument(url_to_scrape)
  
# create soap object
soup = BeautifulSoup(html_document, 'html.parser')

# find all the anchor tags with "href" 
# attribute starting with "https://"
for link in soup.find_all('a', 
                          attrs={'href': re.compile("")}):
    # display the actual urls
    print(link.get('href'))
# Out:
# /
# https://www.fairfaxcounty.gov/search/
# https://www.fairfaxcounty.gov/
# https://www.fairfaxcounty.gov/residents/
# https://www.fairfaxcounty.gov/business/
# https://www.fairfaxcounty.gov/government/
# https://www.fairfaxcounty.gov/
# https://www.fairfaxcounty.gov/services/
# https://www.fairfaxcounty.gov/connect/
# https://www.fairfaxcounty.gov/search/
# #ctl00_smpBreadcrumbs_SkipLink
# http://www.fairfaxcounty.gov
# http://ldsnet.fairfaxcounty.gov/ldsnet/
# LUstreets.aspx?startswith=A
# https://www.fairfaxcounty.gov/publicaffairs/awards/
# https://wcm.fairfaxcounty.gov//topics/sitefeedback
# tel:703-FAIRFAX
# /
# https://www.fairfaxcounty.gov/topics/webaccessibility/
# https://www.fairfaxcounty.gov/topics/languagetranslation/
# https://www.fairfaxcounty.gov/topics/mobile/
# /
# https://www.fairfaxcounty.gov/topics/accessibility/
# https://www.fairfaxcounty.gov/publicaffairs/foia/
# https://www.fairfaxcounty.gov/contact/MailForm.aspx?agId=100387
# /
# https://www.fcps.edu/
# ...

# %%
'http://ldsnet.fairfaxcounty.gov/landusesrch/Default.aspx?strname=Autumn+Glory+Ct'

# %%
from bs4.element import Comment
import urllib.request


def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True


def text_from_html(body):
    soup = BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return u" ".join(t.strip() for t in visible_texts)


link = 'http://ldsnet.fairfaxcounty.gov/landusesrch/Default.aspx?strname=Marmion+Dr'
html = urllib.request.urlopen(link).read()
print(text_from_html(html))
# Out:
#                                Toggle navigation        menu                      RESIDENTS      BUSINESS      GOVERNMENT             SERVICES      CONNECT      SEARCH                    homepage   land development system   Land Use Search               Land Use Search                Start searching for Land Use Information by entering a Fairfax County Address.  Street name suggestion will appear as you type. Use Arrow keys or mouse to select from the list.        Number   Street Name *     Search Address:        Street Name Help          * required                           Awards      Site Feedback        Main Address       12000 Government Center Pkwy Fairfax, VA 22035   Phone    703-FAIRFAX    TTY 711      Site Tools   Site Tools     Website Accessibility    Translate    Download Mobile App      Support   Support     ADA Accessibility    FOIA Requests    Website Administrator      Additional Resources   Additional Resources     Fairfax County Public Schools    Economic Developmen
# ...
